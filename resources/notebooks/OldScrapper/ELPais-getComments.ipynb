# %%
import sys
from PyQt5 import QtCore, QtWidgets, QtWebEngineWidgets
from lxml import html as htmlRenderer
import requests
import json
from datetime import date
import datetime
from random import *

# %%
def render(source_url):
    """Fully render HTML, JavaScript and all."""

    import sys
    from PyQt5.QtWidgets import QApplication
    from PyQt5.QtCore import QUrl
    from PyQt5.QtWebEngineWidgets import QWebEngineView

    class Render(QWebEngineView):
        def __init__(self, url):
            self.html = None
            self.app = QApplication(sys.argv)
            QWebEngineView.__init__(self)
            self.loadFinished.connect(self._loadFinished)
            #self.setHtml(html)
            self.load(QUrl(url))
            self.app.exec_()

        def _loadFinished(self, result):
            # This is an async call, you need to wait for this
            # to be called before closing the app
            self.page().toHtml(self._callable)

        def _callable(self, data):
            self.html = data
            # Data has been stored, it's safe to quit the app
            self.app.quit()

    return Render(source_url).html

# %%
url="https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html"
renderUrl = render(url)
renderedPage = htmlRenderer.fromstring(renderUrl)

# %%
auxLinks = renderedPage.xpath("//span[@class='boton-contador']")

# %%
commentEl = auxLinks[0]
commentElVal = commentEl.get("id").split("_")
idNoticia = commentElVal[len(commentElVal)-1]
perfiloHiloId = "_{}".format(idNoticia)

# %%
# Get Comments Info

urlInfoComments = "https://elpais.com/ThreadeskupSimple"
rnd = random()

infoArg = {
    "action": "info",
    "th": idNoticia,
    "rnd": rnd
}

# %%
responseInfoComments = requests.get(urlInfoComments, infoArg)

# %%
responseInfoComments
# Out:
# <Response [200]>

# %%
infoComments = json.loads(responseInfoComments.text)

# %%
infoComments
# Out:
# {'info': '',
#  'perfilesHilos': {'_1564664936-bca025601586bc5a00ef0c26fdd878f6': {'caducidad': 1565961151,
#    'estado': 0,
#    'msgs_respuesta': None,
#    'num_respuestas': None,
#    'numero_mensajes': 120,
#    'numero_mensajes_opinadores': 16,
#    'premoderacion': 1,
#    'tipo': 'comentarios',
#    'titulo_noticia': 'Tres%20millones%20de%20hect%C3%A1reas%20de%20bosques%20arden%20en%20Rusia',
#    'url_asociada': 'http://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html'}},
#  'status': 'ok'}

# %%
pages = infoComments["perfilesHilos"][perfiloHiloId]["numero_mensajes"]//50
if (infoComments["perfilesHilos"][perfiloHiloId]["numero_mensajes"]%50 > 0) :
    pages = pages + 1

pages
# Out:
# 3

# %%
# https://elpais.com/OuteskupSimple?s=&rnd=0.5448952094970048&th=2&msg=1564664936-bca025601586bc5a00ef0c26fdd878f6&p=2&nummsg=120&tt=1
# s=
# &rnd=0.5448952094970048
# &th=2
# &msg=1564664936-bca025601586bc5a00ef0c26fdd878f6
# &p=2
# &nummsg=120
# &tt=1
rnd = random()
commentsArgs = {
    "s": "",
    "rnd": rnd,
    "th": 1,
    "msg": idNoticia,
    "nummsg": infoComments["perfilesHilos"][perfiloHiloId]["numero_mensajes"],
    "tt": 1
}

# %%
urlGetComments = "https://elpais.com/OuteskupSimple"
responseComments = requests.get(urlGetComments, commentsArgs)

# %%
commentsResponse = json.loads(responseComments.text)

# %%
commentsResponse
# Out:
# {'errorCode': 0,
#  'mensajes': [{'CopiaEnTablones': 't1-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Tres millones de hectáreas de bosques arden en Rusia <a title="http://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html" target="_blank" href="http://cort.as/-MEWg">http://cort.as/-MEWg</a></p>',
#    'extra_json': '{"lang":"es","edition":"undefined"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'level': 0,
#    'opinador': 1,
#    'origen': 'ep',
#    'reenvio': 0,
#    'tsMensaje': 1564664936,
#    'usuarioOrigen': 'registrador',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-mapereira,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Aún no toman en serio el calentamiento global. Las pérdidas económicas son mayores cada año. </p><p>Los gobiernos deben invertir para cambiar la matriz de energía, que aún sigue siendo petróleo, gas y carbón porque por más que crecen las energías verdes, cada año se necesita más y más energía: <a title="http://cort.as/9VGN" target="_blank" href="http://cort.as/9VGN">http://cort.as/9VGN</a> no hay que dejarlo al mercado, porque se está yendo más lento de lo que el planeta necesita. <a title="http://cort.as/-0X8m" target="_blank" href="http://cort.as/-0X8m">http://cort.as/-0X8m</a> No hay otra solución. </p><p>Asimismo, debería haber un plan global para reponer árboles, ya que sólo en América Latina todos los años se pierde por la tala una superficie equivalente a Bélgica, es como si le quitaras al mundo un pedazito de pulmón. </p><p>Sólo una ayuda divina de la jerarquía espiritual, que se presentará en poco tiempo, con Maitreya, Jesús, Koot homi, Morya, Hilarión, Rackozy, Pablo el Veneciano y otros maestros, nos presentarán el panorama de crisis completo, no sólo ecológico, sino en varios aspectos: <a title="http://cort.as/8lVy" target="_blank" href="http://cort.as/8lVy">http://cort.as/8lVy</a> Este será el evento más importante en la historia de la humanidad. Los problemas que afronta el mundo son varios: <a title="http://cort.as/djmz" target="_blank" href="http://cort.as/djmz">http://cort.as/djmz</a> <a title="http://cort.as/-99f3" target="_blank" href="http://cort.as/-99f3">http://cort.as/-99f3</a></p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564666865-0e7f4f1fd10e045eff5f938aae08cb08',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XULrZn8AAQEAAFIDE9MAAAAp',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '-666',
#    'tsMensaje': 1564666865,
#    'usuarioOrigen': 'mapereira',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_91d27da053f285c4,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Esto es un verdadero desastre ecológico, pues es zona de turba y si está seca puede estar eso ardiendo mucho tiempo, además de la cantidad ingente de CO2 que emite. 3 millones de hectáreas no es poco</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564667565-c4389af6e79efa23d1bbe0a867758c45',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XULtLX8AAQEAAAakgvcAAAA1',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.013063106,"TOXICITY_INSULT_EXPERIMENTAL":0.038505293,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0037337448,"SEVERE_TOXICITY_EXPERIMENTAL":0.0025452815,"TOXICITY_THREAT_EXPERIMENTAL":0.02319202,"TOXICITY_EXPERIMENTAL":0.040093828}',
#    'tsMensaje': 1564667565,
#    'usuarioOrigen': 'xwx_91d27da053f285c4',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-kbz,t4-xwx_91d27da053f285c4',
#    'autorMsgRespuesta': 'xwx_91d27da053f285c4',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Esto ocurre cada año desde tiempos inmemorables. Y no le pasa nada a la planeta. Estos incendios no están debidos como los incendios en España por el afán de recalificar tierras.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564694118-9f9963963593f790376b7d2661cb2c53',
#    'idMsgRespuesta': '1564667565-c4389af6e79efa23d1bbe0a867758c45',
#    'id_related_msgs': 'XUNVoH8AAQEAAFbCMT0AAAA4',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.17654966,"TOXICITY_INSULT_EXPERIMENTAL":0.073691666,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0048077474,"SEVERE_TOXICITY_EXPERIMENTAL":0.010724811,"TOXICITY_THREAT_EXPERIMENTAL":0.06724624,"TOXICITY_EXPERIMENTAL":0.07955089}',
#    'tsMensaje': 1564694118,
#    'usuarioOrigen': 'kbz',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_a39901c1357825a4,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Estas cantidades inabarcables ,me dan risa</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564668416-c7352b4541b142a231ec8e2dbbb9994c',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XULxsn8AAQEAABaViAkAAAA9',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.016853519,"TOXICITY_INSULT_EXPERIMENTAL":0.040601753,"TOXICITY_OBSCENE_EXPERIMENTAL":0.007968331,"SEVERE_TOXICITY_EXPERIMENTAL":0.0029831852,"TOXICITY_THREAT_EXPERIMENTAL":0.020531705,"TOXICITY_EXPERIMENTAL":0.04815579}',
#    'tsMensaje': 1564668416,
#    'usuarioOrigen': 'xwx_a39901c1357825a4',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-mjmingo9,t4-xwx_a39901c1357825a4',
#    'autorMsgRespuesta': 'xwx_a39901c1357825a4',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>30.000 km2, el tamaño aproximado de Galicia, algo "inabarcable" sin duda. Lo suyo debe ser la risa tonta del que poco sabe.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564673999-7c47db8d7e93ef2d42fa300682b7c1b5',
#    'idMsgRespuesta': '1564668416-c7352b4541b142a231ec8e2dbbb9994c',
#    'id_related_msgs': 'XUMG938AAQEAAHxtKK4AAAAq',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.16405034,"TOXICITY_INSULT_EXPERIMENTAL":0.64777946,"TOXICITY_OBSCENE_EXPERIMENTAL":0.09132544,"SEVERE_TOXICITY_EXPERIMENTAL":0.04082168,"TOXICITY_THREAT_EXPERIMENTAL":0.056435,"TOXICITY_EXPERIMENTAL":0.62429017}',
#    'tsMensaje': 1564673999,
#    'usuarioOrigen': 'mjmingo9',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-claudio3,t4-mjmingo9',
#    'autorMsgRespuesta': 'mjmingo9',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Desde luego, aun considerando la enorme extensión que tiene Siberia (Unos 10 millones de Km/2) es una catástrofe en toda  regla que ardan 30.000 km/2. En esa extensión caben 4 provincias del tamaña de la de Málaga.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564675453-065a8b0770d1fd0227d177a7f259f1a7',
#    'idMsgRespuesta': '1564673999-7c47db8d7e93ef2d42fa300682b7c1b5',
#    'id_related_msgs': 'XUMI2H8AAQEAAG3M6vYAAAAi',
#    'level': 3,
#    'opinador': 1,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.063188486,"TOXICITY_INSULT_EXPERIMENTAL":0.056262184,"TOXICITY_OBSCENE_EXPERIMENTAL":0.005005183,"SEVERE_TOXICITY_EXPERIMENTAL":0.007153201,"TOXICITY_THREAT_EXPERIMENTAL":0.052965317,"TOXICITY_EXPERIMENTAL":0.062003765}',
#    'tsMensaje': 1564675453,
#    'usuarioOrigen': 'claudio3',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-psalazar,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>3 millones de hectáreas son 30.000km², el tamaño de Galicia, es un auténtico desastre. Espero que se solucione pronto.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564669239-ed80bb62c0b7b64805d5609b1198a50a',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUL01H8AAQEAAALp5DQAAAAv',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.13962784,"TOXICITY_INSULT_EXPERIMENTAL":0.11567942,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0031876268,"SEVERE_TOXICITY_EXPERIMENTAL":0.010996566,"TOXICITY_THREAT_EXPERIMENTAL":0.045695692,"TOXICITY_EXPERIMENTAL":0.11003473}',
#    'tsMensaje': 1564669239,
#    'usuarioOrigen': 'psalazar',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-kbz,t4-psalazar',
#    'autorMsgRespuesta': 'psalazar',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Tranqi, no pasa nada. El ejército hará buen ejercicio bombardeando (para hacer bandas sin árboles). No sé si tiene sentido.  El mapa está tan exajerada como solo el país puede exagerar.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564694240-039d19321adb2e21d36a2d56935a8eab',
#    'idMsgRespuesta': '1564669239-ed80bb62c0b7b64805d5609b1198a50a',
#    'id_related_msgs': 'XUNVoH8AAQEAAFbCMT0AAAA4',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.07785723,"TOXICITY_INSULT_EXPERIMENTAL":0.09466133,"TOXICITY_OBSCENE_EXPERIMENTAL":0.018031482,"SEVERE_TOXICITY_EXPERIMENTAL":0.09761416,"TOXICITY_THREAT_EXPERIMENTAL":0.63429135,"TOXICITY_EXPERIMENTAL":0.1272555}',
#    'tsMensaje': 1564694240,
#    'usuarioOrigen': 'kbz',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_b965d709c03bc5b8,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>El político dice : no vale la pena luchar contra el fuego. Vale más lo que enviamos a luchar contra el fuego que lo que se quema. Y ese es el problema. Los bosques no cotizan en bolsa, no valen nada desde el punto de vista capitalista. Sólo su transformación en viviendas y comercios y fábricas. Son los árboles los que nos permiten respirar. Y lo hacen gratis. Algo inconcebible en nuestro sistema económico.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564671114-7bc33db9ae6ee16157a93952c9958a19',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUL6On8AAQEAADikiC8AAAAw',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.016279234,"TOXICITY_INSULT_EXPERIMENTAL":0.047377627,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0036454229,"SEVERE_TOXICITY_EXPERIMENTAL":0.007394836,"TOXICITY_THREAT_EXPERIMENTAL":0.17255184,"TOXICITY_EXPERIMENTAL":0.058499143}',
#    'tsMensaje': 1564671114,
#    'usuarioOrigen': 'xwx_b965d709c03bc5b8',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_6a6021bf0e38c5be,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Lo de la Amazonia es un topicazo aunque haya que protegerla. La Taiga o bosque boreal de Eurasia es el verdadero pulmón del planeta y su protección debería ser un compromiso de todos los paises. La extensión del desastre es descomunal.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564671632-d3a3545fbe998241cccbb7b89467ad2a',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUL9WH8AAQEAAAtSp1gAAAAp',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.113003455,"TOXICITY_INSULT_EXPERIMENTAL":0.06635242,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0036797593,"SEVERE_TOXICITY_EXPERIMENTAL":0.0070929523,"TOXICITY_THREAT_EXPERIMENTAL":0.022001034,"TOXICITY_EXPERIMENTAL":0.07367319}',
#    'tsMensaje': 1564671632,
#    'usuarioOrigen': 'xwx_6a6021bf0e38c5be',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-cientifico,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>El cambio climático ya está aquí y es irreversible. Bienvenidos al apocalipsis.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564673999-a50fc84730db37ea145f6d0c23559364',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUMHaX8AAQEAAE7bnwgAAAAS',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.028872376,"TOXICITY_INSULT_EXPERIMENTAL":0.07119265,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0027608555,"SEVERE_TOXICITY_EXPERIMENTAL":0.0047568763,"TOXICITY_THREAT_EXPERIMENTAL":0.036184266,"TOXICITY_EXPERIMENTAL":0.07389567}',
#    'tsMensaje': 1564673999,
#    'usuarioOrigen': 'cientifico',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-anonimo_1001,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>A mí lo que me ha dejado más preocupado es que Estados Unidos se haya ofrecido a ayudar, a un país "enemigo" y encima en un tema ambiental, sabiendo de la posición del actual presidente sobre este asunto. Realmente mal debe pintar el tema para llegar a ese punto.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564675133-c0a3697e967e52ba6585678ca6163696',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUMLcH8AAQEAADBMZf8AAAAS',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.1495254,"TOXICITY_INSULT_EXPERIMENTAL":0.12226479,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0040587056,"SEVERE_TOXICITY_EXPERIMENTAL":0.008344395,"TOXICITY_THREAT_EXPERIMENTAL":0.023186471,"TOXICITY_EXPERIMENTAL":0.111653954}',
#    'tsMensaje': 1564675133,
#    'usuarioOrigen': 'anonimo_1001',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_1315288e75236582,t4-anonimo_1001',
#    'autorMsgRespuesta': 'anonimo_1001',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Sigues sin verlo. La culpa es de Rajoy.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564675717-80fadcdd8f8961ae803bde4e4ce57b7f',
#    'idMsgRespuesta': '1564675133-c0a3697e967e52ba6585678ca6163696',
#    'id_related_msgs': 'XUMNnX8AAQEAADP84nAAAAAv',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.05232295,"TOXICITY_INSULT_EXPERIMENTAL":0.19890006,"TOXICITY_OBSCENE_EXPERIMENTAL":0.005185522,"SEVERE_TOXICITY_EXPERIMENTAL":0.011075774,"TOXICITY_THREAT_EXPERIMENTAL":0.040862117,"TOXICITY_EXPERIMENTAL":0.19496843}',
#    'tsMensaje': 1564675717,
#    'usuarioOrigen': 'xwx_1315288e75236582',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-blancoxdentroyxfuera,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 1,
#    'cont_adicional': 0,
#    'contenido': '(mensaje borrado)',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564675133-9a04b8cc8298e6730c3c301445b546ff',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUMKfn8AAQEAACNwEkgAAAA8',
#    'level': 1,
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.34268674,"TOXICITY_INSULT_EXPERIMENTAL":0.64606625,"TOXICITY_OBSCENE_EXPERIMENTAL":0.62152356,"SEVERE_TOXICITY_EXPERIMENTAL":0.23226562,"TOXICITY_THREAT_EXPERIMENTAL":0.4182644,"TOXICITY_EXPERIMENTAL":0.63341975}',
#    'tsMensaje': 1564675133,
#    'usuarioOrigen': 'blancoxdentroyxfuera',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_dbef17442ba0c5ce,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Por fin hace algo correcto ese ex funcionario del KGB ante la catástrofe.....</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564675809-43f5cdb0c146da31054ad6bf36551054',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUMMxX8AAQEAAB8eMNYAAAAk',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.022495227,"TOXICITY_INSULT_EXPERIMENTAL":0.12019383,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0039925515,"SEVERE_TOXICITY_EXPERIMENTAL":0.008143962,"TOXICITY_THREAT_EXPERIMENTAL":0.08026297,"TOXICITY_EXPERIMENTAL":0.106116705}',
#    'tsMensaje': 1564675809,
#    'usuarioOrigen': 'xwx_dbef17442ba0c5ce',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-glopllu,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Todo el mundo tiene ingentes cantidades de material para destruir, para matar, para exterminar pero curiosamente ningún país tiene los suficientes medios para defenderse de la naturaleza, de la devastación del fuego, de los huracanes, de las sequías, etc, etc... Creo que deberíamos pensar muy bien cuáles son nuestras prioridades,</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564675828-dedc710c4675467cbfdc99adcedc9331',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUMOsH8AAQEAAEsaiGoAAAAp',
#    'level': 1,
#    'opinador': 1,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.07510004,"TOXICITY_INSULT_EXPERIMENTAL":0.094462395,"TOXICITY_OBSCENE_EXPERIMENTAL":0.009939905,"SEVERE_TOXICITY_EXPERIMENTAL":0.05448252,"TOXICITY_THREAT_EXPERIMENTAL":0.51235664,"TOXICITY_EXPERIMENTAL":0.1138625}',
#    'tsMensaje': 1564675828,
#    'usuarioOrigen': 'glopllu',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-fedfan,t4-glopllu',
#    'autorMsgRespuesta': 'glopllu',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Es algo increíble...Miro el mapa y me angustio. Lo siguiente será tierra devastada, como el Sáhara.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564678195-e97179a33a819ded07f0eeaa46086f4b',
#    'idMsgRespuesta': '1564675828-dedc710c4675467cbfdc99adcedc9331',
#    'id_related_msgs': 'XUMWrX8AAQEAAFS9ZW0AAAAS',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.34911016,"TOXICITY_INSULT_EXPERIMENTAL":0.117618345,"TOXICITY_OBSCENE_EXPERIMENTAL":0.009561301,"SEVERE_TOXICITY_EXPERIMENTAL":0.07932461,"TOXICITY_THREAT_EXPERIMENTAL":0.44061533,"TOXICITY_EXPERIMENTAL":0.15395059}',
#    'tsMensaje': 1564678195,
#    'usuarioOrigen': 'fedfan',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_506c7caf42366582,t4-glopllu',
#    'autorMsgRespuesta': 'glopllu',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Tiene una solución dificil lo de los incendios forestales, la mayoría parece ser que son provocados, y el que lo hace busca la mayor ventaja posible para que tenga éxito. Creo que habría que extremar la prevención... una vez el fuego  cobra fuerza, los aviones le dan risa. Penas fuertes para los delincuentes, pero no de cárcel, sino de limpieza de montes de por vida útil.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564689516-ca65bcb0479e751ac1fc3b5399252ad2',
#    'idMsgRespuesta': '1564675828-dedc710c4675467cbfdc99adcedc9331',
#    'id_related_msgs': 'XUNCx38AAQEAAHCM9u8AAABU',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.034902953,"TOXICITY_INSULT_EXPERIMENTAL":0.06871499,"TOXICITY_OBSCENE_EXPERIMENTAL":0.006277826,"SEVERE_TOXICITY_EXPERIMENTAL":0.020409148,"TOXICITY_THREAT_EXPERIMENTAL":0.40503937,"TOXICITY_EXPERIMENTAL":0.08225168}',
#    'tsMensaje': 1564689516,
#    'usuarioOrigen': 'xwx_506c7caf42366582',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_cd5f42d2869945cc,t4-xwx_506c7caf42366582',
#    'autorMsgRespuesta': 'xwx_506c7caf42366582',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>40. - Los incendios forestales que arrasan estos días vastos territorios de Siberia podrían ser deliberados, para encubrir la tala ilegal, admitió el primer ministro de Rusia, Dmitri Medvédev. 01.08.2019 </p><p><a title="http://cort.as/-MHAf" target="_blank" href="http://cort.as/-MHAf">http://cort.as/-MHAf</a></p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564704785-59b202e4aaecceefe9818177496086f1',
#    'idMsgRespuesta': '1564689516-ca65bcb0479e751ac1fc3b5399252ad2',
#    'id_related_msgs': 'XUN3WX8AAQEAAE84ktIAAAAM',
#    'level': 3,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '-666',
#    'tsMensaje': 1564704785,
#    'usuarioOrigen': 'xwx_cd5f42d2869945cc',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-frippy,t4-xwx_506c7caf42366582',
#    'autorMsgRespuesta': 'xwx_506c7caf42366582',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Limpiar bosques inaccesibles es como barrer la arena del desierto. Absurdo.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564740698-a3fd027477bafc9a951caeb4102ec056',
#    'idMsgRespuesta': '1564689516-ca65bcb0479e751ac1fc3b5399252ad2',
#    'id_related_msgs': 'XUQKRn8AAQEAAE@44wEAAAAF',
#    'level': 3,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.009082615,"TOXICITY_INSULT_EXPERIMENTAL":0.026623383,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0033145363,"SEVERE_TOXICITY_EXPERIMENTAL":0.0019602352,"TOXICITY_THREAT_EXPERIMENTAL":0.011790298,"TOXICITY_EXPERIMENTAL":0.031288613}',
#    'tsMensaje': 1564740698,
#    'usuarioOrigen': 'frippy',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_506c7caf42366582,t4-frippy',
#    'autorMsgRespuesta': 'frippy',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Inaccesibles para una de las mayores potencias mundiales, con la de máquinas que hay, eso hace 100 años aún.</p>',
#    'extra_json': '{"lang":"es","edition":"undefined"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564772262-edb95ea5bf3e851d0d4ef18e53cd3d98',
#    'idMsgRespuesta': '1564740698-a3fd027477bafc9a951caeb4102ec056',
#    'level': 4,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'tsMensaje': 1564772262,
#    'usuarioOrigen': 'xwx_506c7caf42366582',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_8e716c2fbcf925d3,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Espeluznante. </p><p><a title="http://cort.as/-MFA0" target="_blank" href="http://cort.as/-MFA0">http://cort.as/-MFA0</a></p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564676421-1bb2b51d3268396115eeae7bffa7c8b1',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUMRCX8AAQEAAA5j2DAAAAAe',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '-666',
#    'tsMensaje': 1564676421,
#    'usuarioOrigen': 'xwx_8e716c2fbcf925d3',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-tonterias,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>A Putin le importa más si su perro estornuda</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564676881-490af30d06aa5e3ce6a18f9111fcad97',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUMRoX8AAQEAADGLv7sAAAAt',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.45586002,"TOXICITY_INSULT_EXPERIMENTAL":0.739479,"TOXICITY_OBSCENE_EXPERIMENTAL":0.41201487,"SEVERE_TOXICITY_EXPERIMENTAL":0.39204976,"TOXICITY_THREAT_EXPERIMENTAL":0.5092619,"TOXICITY_EXPERIMENTAL":0.7180089}',
#    'tsMensaje': 1564676881,
#    'usuarioOrigen': 'tonterias',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_a72d538f537aa5be,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Putin hizo las maniobras mas grandes de Rusia ,mas de 300 mil soldados y tanques aviones ,ect ,todo para inutil proposito de mostrar musculo ,aunque si fuera contra la OTAN es en vano ,pero para salvar la naturaleza ,no mueben un dedo ,hasta que el fuego llegue al krenlin ,no es negocio apagarlo ,y trump de lame ojos ,que se retiro del plan de salvar nuestra tierra ,quiere poner el dinero de los americanos a salvar los bosques rusos ,que desverguenza ,politica ,las relaciones con rusia no seran mejores kientras Putin sea el lider ,solo trump por los motivos escondidos que tiene ,le trata de amigo ,sabe Dios ,que le sabe ,algun dia lo sabremos ,cuando Trump salga del poder ,Putin le pasara la cuenta ,ese no es amigo de nadie ,</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564677460-5167ca0aedf4939f989fd084ee1e1e65',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUMTXn8AAQEAABI3YH8AAAAG',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.48126316,"TOXICITY_INSULT_EXPERIMENTAL":0.6626381,"TOXICITY_OBSCENE_EXPERIMENTAL":0.21241534,"SEVERE_TOXICITY_EXPERIMENTAL":0.14640534,"TOXICITY_THREAT_EXPERIMENTAL":0.2503234,"TOXICITY_EXPERIMENTAL":0.6242663}',
#    'tsMensaje': 1564677460,
#    'usuarioOrigen': 'xwx_a72d538f537aa5be',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-pifostio,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>No se cuanto más hace falta para que la Derecha empiece a reconocer que lo del cambio climático va en serio y no es ninguna patraña marxista. Y esto lo dice alguien que se considera más bien conservador y de derechas</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564677826-f818ea1982bdf7f114aab99e92376070',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUMWHn8AAQEAABcXVi4AAAAb',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '-666',
#    'tsMensaje': 1564677826,
#    'usuarioOrigen': 'pifostio',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_1315288e75236582,t4-pifostio',
#    'autorMsgRespuesta': 'pifostio',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>sí, es verdad, es una concienzuda reflexión y creo que la intelectualidad científica no se lo ha planteado. Hay que exterminar de una vez a la Derecha y a los conservantes conservadores que son la causa, el medio y el fin del por-blema medioambiental. Más I+D+I y menos VOX.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564678227-f83625e2c0106dcdcceb5dd4e3cc9bb2',
#    'idMsgRespuesta': '1564677826-f818ea1982bdf7f114aab99e92376070',
#    'id_related_msgs': 'XUMO0n8AAQEAADRRX8QAAAAO',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '-666',
#    'tsMensaje': 1564678227,
#    'usuarioOrigen': 'xwx_1315288e75236582',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-pifostio,t4-xwx_1315288e75236582',
#    'autorMsgRespuesta': 'xwx_1315288e75236582',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Es que yo soy votante de VOX, a pesar de que nieguen el cambio climático.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564685199-0ea96f84f4497131a48f1b572a63cf65',
#    'idMsgRespuesta': '1564678227-f83625e2c0106dcdcceb5dd4e3cc9bb2',
#    'id_related_msgs': 'XUMwuX8AAQEAAB@qSCQAAAAb',
#    'level': 3,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.014573893,"TOXICITY_INSULT_EXPERIMENTAL":0.016345873,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0021798196,"SEVERE_TOXICITY_EXPERIMENTAL":0.0016624475,"TOXICITY_THREAT_EXPERIMENTAL":0.006402807,"TOXICITY_EXPERIMENTAL":0.019087467}',
#    'tsMensaje': 1564685199,
#    'usuarioOrigen': 'pifostio',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_47580b46487aa5d2,t4-xwx_1315288e75236582',
#    'autorMsgRespuesta': 'xwx_1315288e75236582',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Que pereza dais</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564685718-374ffd927aa48e061e16cc0a0fb96b67',
#    'idMsgRespuesta': '1564678227-f83625e2c0106dcdcceb5dd4e3cc9bb2',
#    'id_related_msgs': 'XUMziH8AAQEAAAbDO9MAAAAd',
#    'level': 3,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.051920664,"TOXICITY_INSULT_EXPERIMENTAL":0.3546458,"TOXICITY_OBSCENE_EXPERIMENTAL":0.096598335,"SEVERE_TOXICITY_EXPERIMENTAL":0.050176445,"TOXICITY_THREAT_EXPERIMENTAL":0.10283749,"TOXICITY_EXPERIMENTAL":0.34849268}',
#    'tsMensaje': 1564685718,
#    'usuarioOrigen': 'xwx_47580b46487aa5d2',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-kissin,t4-pifostio',
#    'autorMsgRespuesta': 'pifostio',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Igual, si dejarais de votarles, dejarían de hablar patrañas.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564687664-d9eb1167dad50b25116e8a1cc7755513',
#    'idMsgRespuesta': '1564677826-f818ea1982bdf7f114aab99e92376070',
#    'id_related_msgs': 'XUM8Zn8AAQEAAGojalgAAAAY',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.29416397,"TOXICITY_INSULT_EXPERIMENTAL":0.6491106,"TOXICITY_OBSCENE_EXPERIMENTAL":0.16343956,"SEVERE_TOXICITY_EXPERIMENTAL":0.12359345,"TOXICITY_THREAT_EXPERIMENTAL":0.24131517,"TOXICITY_EXPERIMENTAL":0.6240269}',
#    'tsMensaje': 1564687664,
#    'usuarioOrigen': 'kissin',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-cuchas,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>¿Existe la tecnología para provocar lluvias artificialmente?</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564678348-7fb0d428e1659f112bc9f03d68459335',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUMXzn8AAQEAAD6jqDQAAAAW',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.0078694215,"TOXICITY_INSULT_EXPERIMENTAL":0.011300553,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0026305479,"SEVERE_TOXICITY_EXPERIMENTAL":0.0030025255,"TOXICITY_THREAT_EXPERIMENTAL":0.03843056,"TOXICITY_EXPERIMENTAL":0.02199586}',
#    'tsMensaje': 1564678348,
#    'usuarioOrigen': 'cuchas',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-heferstion,t4-cuchas',
#    'autorMsgRespuesta': 'cuchas',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Y nevadas.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564683833-7627e73430988cd0234f7a4c45713804',
#    'idMsgRespuesta': '1564678348-7fb0d428e1659f112bc9f03d68459335',
#    'id_related_msgs': 'XUMtY38AAQEAAGBZ9M0AAAAu',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.006844504,"TOXICITY_INSULT_EXPERIMENTAL":0.0028755525,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0034633027,"SEVERE_TOXICITY_EXPERIMENTAL":0.0035222017,"TOXICITY_THREAT_EXPERIMENTAL":0.009413793,"TOXICITY_EXPERIMENTAL":0.0052578617}',
#    'tsMensaje': 1564683833,
#    'usuarioOrigen': 'heferstion',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-jaimer,t4-cuchas',
#    'autorMsgRespuesta': 'cuchas',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Creo que sí; pero se requiere de humedad existente en la atmósfera claro. Utilizan yoduro de plata.  En cualquier caso no creo que sea facil; de lo contrario se haría con frecuencia.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564684715-a2beeef17815d601f41e9c65226070b2',
#    'idMsgRespuesta': '1564678348-7fb0d428e1659f112bc9f03d68459335',
#    'id_related_msgs': 'XUMw8H8AAQEAAARCdJwAAAAe',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.0069219037,"TOXICITY_INSULT_EXPERIMENTAL":0.009971019,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0018875237,"SEVERE_TOXICITY_EXPERIMENTAL":0.0019867981,"TOXICITY_THREAT_EXPERIMENTAL":0.012641951,"TOXICITY_EXPERIMENTAL":0.015336636}',
#    'tsMensaje': 1564684715,
#    'usuarioOrigen': 'jaimer',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_3239024844b5c5b8,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Han tardado 7 días en empezar a decir algo sobre el desastre ambiental de Siberia... aqui hablamos más de la Pantoja o de alguna pijada LGTBI </p><p>Una amiga siberiana me explicó el desastre y yo le dije aqui no han dicho NADAAA... Ciudades llenas de humo.. bosques calcinados por miles de kilómetros cuadrados.. y El Pais ni mu.... ahora 7 días despues empiezan a decir algo, cuando Trump ofrece ayuda... Cada semana que pasa la gente que trabaja  en EL PAIS  son peores... gastan tiempo y recursos en chorradas de lavado de coco y de las cosas que afectan de verdad no dicen nada o las dicen sesgadas... </p><p>El Clima ha cambiado durante toda la historia el Calentamiento Global es un cuento que se han sacado de la manga para subir impuestos y cobrar por "vender aire" cualquiera que lea historia sabe que ha habido periodos de grandes sequias, desiertos que se han tragado civilizaciones, inundaciones bíblicas, inviernos durísimos que provocaban grandes migraciones.. El Clima siempre es variable.. asi ha sido y asi sera.. pero estos jetas quieren poner un IMPUESTITO AL TEMA..  a chupar del CLIMA.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564678470-6af0727633476e61d2b06f34a9ac668f',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUMXlX8AAQEAAGwVeHAAAAAG',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '-666',
#    'tsMensaje': 1564678470,
#    'usuarioOrigen': 'xwx_3239024844b5c5b8',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-ahmonge,t4-xwx_3239024844b5c5b8',
#    'autorMsgRespuesta': 'xwx_3239024844b5c5b8',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Pues como cualquiera que haya leído la historia sabe, esto es normal, siempre ha habido grandes incendios en los bosques, nada de qué preocuparse. El País le ha hecho caso ignorando la noticia; ¿por qué se mosquea con el periódico?</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564679027-2f7f4accd0bc73fc8c3d2cf94d7d7109',
#    'idMsgRespuesta': '1564678470-6af0727633476e61d2b06f34a9ac668f',
#    'id_related_msgs': 'XUMZyX8AAQEAABy1hPUAAAAR',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.02378576,"TOXICITY_INSULT_EXPERIMENTAL":0.11658782,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0082090655,"SEVERE_TOXICITY_EXPERIMENTAL":0.005624188,"TOXICITY_THREAT_EXPERIMENTAL":0.05277404,"TOXICITY_EXPERIMENTAL":0.09538234}',
#    'tsMensaje': 1564679027,
#    'usuarioOrigen': 'ahmonge',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-pifostio,t4-xwx_3239024844b5c5b8',
#    'autorMsgRespuesta': 'xwx_3239024844b5c5b8',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Cansa un poco leer siempre los mismos argumentos falaces. El que el clima siempre varíe no demuestra que el cambio climático actual sea un cuento. El clima varía, sí, pero las variaciones cíclicas son mucho más lentas que lo que estamos viendo ahora. Y cuando ha habido cambios bruscos, siempre se han tenido que deber a algo que los causara: caída de un gran meteorito, fuerte actividad volcánica, cambios en la configuración de los continentes y las aguas... Pero, ¿a qué se debe el calentamiento actual, que está ocurriendo a un ritmo sin precedentes conocidos? A los ciclos solares no. A cambios en la órbita terrestre tampoco, ni a la caída de un meteorito, ni a la actividad volcánica. En cambio, sí está demostrado que el CO2 ha visto aumentada su concentración en la atmósfera debido a la actividad humana, que es, además, un gas de efecto invernadero. ¿Hay alguna otra hipótesis alternativa?</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564685169-3c23a294a5c407a6ef1da5e0085f2314',
#    'idMsgRespuesta': '1564678470-6af0727633476e61d2b06f34a9ac668f',
#    'id_related_msgs': 'XUMwuX8AAQEAAB@qSCQAAAAb',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '-666',
#    'tsMensaje': 1564685169,
#    'usuarioOrigen': 'pifostio',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_682cf555e75045ac,t4-pifostio',
#    'autorMsgRespuesta': 'pifostio',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>El clima siempre ha variado, pero el hombre está haciendo que varíe miles de veces más rápido, ha destruido el equilibrio natural.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564696066-005cf676923acfb50d91c5b1fc14714f',
#    'idMsgRespuesta': '1564685169-3c23a294a5c407a6ef1da5e0085f2314',
#    'id_related_msgs': 'XUNczX8AAQEAACSSHA8AAAAc',
#    'level': 3,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.054868184,"TOXICITY_INSULT_EXPERIMENTAL":0.04664319,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0018314649,"SEVERE_TOXICITY_EXPERIMENTAL":0.0028578718,"TOXICITY_THREAT_EXPERIMENTAL":0.009712466,"TOXICITY_EXPERIMENTAL":0.05012087}',
#    'tsMensaje': 1564696066,
#    'usuarioOrigen': 'xwx_682cf555e75045ac',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-bill_takoff,t4-xwx_682cf555e75045ac',
#    'autorMsgRespuesta': 'xwx_682cf555e75045ac',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Lo que tenemos que hacer es no comprar nada que contenga plástico por ejemplo. Porque es absurdo cuando cualquier artículo pequeño, aunque sean 10 tornillos, está empaqueteado en un montón de plástico.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564696349-c997ec519b2a85edcac02fd3fc83c6f8',
#    'idMsgRespuesta': '1564696066-005cf676923acfb50d91c5b1fc14714f',
#    'id_related_msgs': 'XUNZ4n8AAQEAAEY9IN4AAAAB',
#    'level': 4,
#    'opinador': 1,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.025010528,"TOXICITY_INSULT_EXPERIMENTAL":0.05771963,"TOXICITY_OBSCENE_EXPERIMENTAL":0.011484432,"SEVERE_TOXICITY_EXPERIMENTAL":0.005122319,"TOXICITY_THREAT_EXPERIMENTAL":0.034794882,"TOXICITY_EXPERIMENTAL":0.06646077}',
#    'tsMensaje': 1564696349,
#    'usuarioOrigen': 'bill_takoff',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-angelito1950,t4-bill_takoff',
#    'autorMsgRespuesta': 'bill_takoff',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Podemos rechazar las bolsas plásticas ,en mi país estamos creando una cultura de rechazo, ves a la gente comprando con bolsas de tela si la compra es mayor , o con las cosas en la mano sin son menores. </p><p>Es poco pero por algo se empieza, hasta los inmigrantesse han ido acostumbrando.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564711362-7b8343c0eaf166bb08abdcf72f70b296',
#    'idMsgRespuesta': '1564696349-c997ec519b2a85edcac02fd3fc83c6f8',
#    'id_related_msgs': 'XUOWvn8AAQEAAFfealgAAAAb',
#    'level': 5,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '-666',
#    'tsMensaje': 1564711362,
#    'usuarioOrigen': 'angelito1950',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-angelito1950,t4-xwx_682cf555e75045ac',
#    'autorMsgRespuesta': 'xwx_682cf555e75045ac',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Pues en realidad no es miles  de veces más rápido ,  pero la velocidad de cambio supera la velocidad de adaptación del planeta y ahí está el problema . </p><p>Se supone que el excedente de carbono en la atmósfera hace crecer los árboles , pero eso tiene una velocidad mucho menor que aquella a la que descargamos el CO2.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564711543-da7b474541c3a9bc7b62ad4dfe981a2f',
#    'idMsgRespuesta': '1564696066-005cf676923acfb50d91c5b1fc14714f',
#    'id_related_msgs': 'XUOWvn8AAQEAAFfealgAAAAb',
#    'level': 4,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '-666',
#    'tsMensaje': 1564711543,
#    'usuarioOrigen': 'angelito1950',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-frippy,t4-xwx_3239024844b5c5b8',
#    'autorMsgRespuesta': 'xwx_3239024844b5c5b8',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Terraplanista detectado.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564740392-3961dc18dafdaa0e9f354cd577c91710',
#    'idMsgRespuesta': '1564678470-6af0727633476e61d2b06f34a9ac668f',
#    'id_related_msgs': 'XUQKRn8AAQEAAE@44wEAAAAF',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.008991142,"TOXICITY_INSULT_EXPERIMENTAL":0.011182114,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0028693401,"SEVERE_TOXICITY_EXPERIMENTAL":0.004032753,"TOXICITY_THREAT_EXPERIMENTAL":0.044631563,"TOXICITY_EXPERIMENTAL":0.017161379}',
#    'tsMensaje': 1564740392,
#    'usuarioOrigen': 'frippy',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-gbshaw,t4-registrador',
#    'autorMsgRespuesta': 'registrador',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>sería bueno entender que los fuegos en la taiga que no provienen de la mano humana... son beneficiosos en general aunque nuestra visión mediterránea nos diga lo contrario.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564679088-9110701507379478b7db6cbf3b0509e7',
#    'idMsgRespuesta': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'id_related_msgs': 'XUMYJ38AAQEAAFmaAvQAAAAN',
#    'level': 1,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.023419188,"TOXICITY_INSULT_EXPERIMENTAL":0.020624634,"TOXICITY_OBSCENE_EXPERIMENTAL":0.0023301712,"SEVERE_TOXICITY_EXPERIMENTAL":0.0023503879,"TOXICITY_THREAT_EXPERIMENTAL":0.008086074,"TOXICITY_EXPERIMENTAL":0.026164986}',
#    'tsMensaje': 1564679088,
#    'usuarioOrigen': 'gbshaw',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-xwx_dbef17442ba0c5ce,t4-gbshaw',
#    'autorMsgRespuesta': 'gbshaw',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>Vaya zafiedad, como si aquello fuera la sabana africana...........con el permafrost yéndose al garete.</p>',
#    'extra_json': '{"lang":"es","edition":"elpais.com"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
#    'idMsg': '1564679804-2356c396c2c44bfa6a8d8f87a4cc54bd',
#    'idMsgRespuesta': '1564679088-9110701507379478b7db6cbf3b0509e7',
#    'id_related_msgs': 'XUMMxX8AAQEAAB8eMNYAAAAk',
#    'level': 2,
#    'moderacion': 'ok',
#    'opinador': 0,
#    'origen': 'ep',
#    'reenvio': 0,
#    'toxicities': '{"TOXICITY_IDENTITY_ATTACK_EXPERIMENTAL":0.68923,"TOXICITY_INSULT_EXPERIMENTAL":0.24651857,"TOXICITY_OBSCENE_EXPERIMENTAL":0.021560231,"SEVERE_TOXICITY_EXPERIMENTAL":0.08875278,"TOXICITY_THREAT_EXPERIMENTAL":0.11254103,"TOXICITY_EXPERIMENTAL":0.29806602}',
#    'tsMensaje': 1564679804,
#    'usuarioOrigen': 'xwx_dbef17442ba0c5ce',
#    'via': 'web'},
#   {'CopiaEnTablones': 't1-gbshaw,t4-xwx_dbef17442ba0c5ce',
#    'autorMsgRespuesta': 'xwx_dbef17442ba0c5ce',
#    'borrado': 0,
#    'cont_adicional': 0,
#    'contenido': '<p>el permafrost no se va al garete (basicamente pq el calor de un incendio por muy potente que sea no pasa de unos cm hacia abajo.....) por los incendios que por cierto son recurrentes año tras año por accion de los rayos.</p>',
#    'extra_json': '{"lang":"es","edition":"undefined"}',
#    'hayAudio': 0,
#    'hilo': '1564664936-bca025601586bc5a00ef0c26fdd878f6',
# ...
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/3/1A/bill_takoff.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'blancoxdentroyxfuera': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': '',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': '',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'cientifico': {'activo': 0,
#    'alias_bonito': 'cientifico',
#    'apellidos': 'Frade',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Jose Maria',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'claudio3': {'activo': 1,
#    'alias_bonito': 'claudio3',
#    'apellidos': 'Estanislao',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Claudio',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'cuchas': {'activo': 0,
#    'alias_bonito': 'cuchas',
#    'apellidos': 'Pérez',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Javier',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'fedfan': {'activo': 0,
#    'alias_bonito': 'fedfan',
#    'apellidos': 'Mirón',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Manolo',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'frippy': {'activo': 1,
#    'alias_bonito': 'frippy',
#    'apellidos': 'Amores',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'LLoviendo',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/F/5B/frippy.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'gbshaw': {'activo': 0,
#    'alias_bonito': 'gbshaw',
#    'apellidos': 'rodriguez',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'jorge',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'glopllu': {'activo': 1,
#    'alias_bonito': 'glopllu',
#    'apellidos': 'López',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Guillermo',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/7/48/glopllu.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'heferstion': {'activo': 0,
#    'alias_bonito': 'heferstion',
#    'apellidos': 'el Calvo',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'John',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'jaimer': {'activo': 0,
#    'alias_bonito': 'jaimer',
#    'apellidos': 'Mengual',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Jaime',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'jordihurtado': {'activo': 0,
#    'alias_bonito': 'jordihurtado',
#    'apellidos': 'Pardo',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Antonio',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'josechuleton': {'activo': 0,
#    'alias_bonito': 'josechuleton',
#    'apellidos': 'Lou',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Josechu',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'jprn': {'activo': 0,
#    'alias_bonito': 'jprn',
#    'apellidos': 'R. Nogueras',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Pablo',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/C/DE/jprn.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'kbz': {'activo': 1,
#    'alias_bonito': 'kbz',
#    'apellidos': 'jimenez',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'jose',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/5/62/kbz.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'kissin': {'activo': 0,
#    'alias_bonito': 'kissin',
#    'apellidos': 'por aqui',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'uno',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'mapereira': {'activo': 0,
#    'alias_bonito': 'mapereira',
#    'apellidos': 'Pereira',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Martín',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'mjmingo9': {'activo': 0,
#    'alias_bonito': 'mjmingo9',
#    'apellidos': 'Mingo Naval',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Mariano Jesús',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'nelamiko': {'activo': 0,
#    'alias_bonito': 'nelamiko',
#    'apellidos': 'Baquer',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Pablo',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'nessus': {'activo': 0,
#    'alias_bonito': 'nessus',
#    'apellidos': 'Blue',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Deep',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/6/4B/nessus.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'pacoillo': {'activo': 0,
#    'alias_bonito': 'pacoillo',
#    'apellidos': 'Reyes',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Francisco',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'perron314': {'activo': 0,
#    'alias_bonito': 'perron314',
#    'apellidos': 'Ramos',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Javier',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'perthiguez': {'activo': 0,
#    'alias_bonito': 'perthiguez',
#    'apellidos': 'Bis',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Pértiguez',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/6/31/perthiguez.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'pifostio': {'activo': 0,
#    'alias_bonito': 'pifostio',
#    'apellidos': 'Asenjo',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Torcuato',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'psalazar': {'activo': 0,
#    'alias_bonito': 'psalazar',
#    'apellidos': 'Navalón',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Pablo',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'registrador': {'activo': 0,
#    'alias_bonito': 'registrador',
#    'apellidos': 'EPET',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Registrador',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'tonterias': {'activo': 0,
#    'alias_bonito': 'tonterias',
#    'apellidos': 'Rivers',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Mike',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/3/B6/tonterias.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'vientoquevayviene': {'activo': 0,
#    'alias_bonito': 'vientoquevayviene',
#    'apellidos': 'Y Viene',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Viento Que Va',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/6/81/vientoquevayviene.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xixidoc': {'activo': 0,
#    'alias_bonito': 'xixidoc',
#    'apellidos': 'Huilo',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'putin',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/7/41/xixidoc.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_1315288e75236582': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Muñoz',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Arturo J.',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_1e14a176217b45a5': {'activo': 0,
#    'alias_bonito': 'guezrodri',
#    'apellidos': 'Rodriguez',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Rodri',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_21b36bfac5a5c5a1': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Chan',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Yosy',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_3239024844b5c5b8': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Andersson',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Frank',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_3dab830963d96578': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Gomez',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Francisco',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_47580b46487aa5d2': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'C ciento treinta y siete',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Rick Sanchez',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_506c7caf42366582': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'aqui',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Desde',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_56fa13ad73ba457a': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Romero',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Diego',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_59d14448e1a065a6': {'activo': 1,
#    'alias_bonito': '',
#    'apellidos': 'Pones',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Nacho',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_682cf555e75045ac': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'piripi',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Juan',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_6a6021bf0e38c5be': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Franquiciado',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Paisano',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/8/35/xwx_6a6021bf0e38c5be.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_78e09a8866702593': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Zapata',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Rafael',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_8e716c2fbcf925d3': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Gelat',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Timonet',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_91d27da053f285c4': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Namibiano',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Ray',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_a39901c1357825a4': {'activo': 1,
#    'alias_bonito': '',
#    'apellidos': 'Martinez',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Raul',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_a72d538f537aa5be': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Mendez',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'yisel menfez',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/F/38/xwx_a72d538f537aa5be.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_aa7911dc9a462593': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Charriere',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Dominique',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_b7cb0c7253ce05d1': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Gallagher',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Frank',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_b965d709c03bc5b8': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Peñafiel',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Rafael',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/7/B3/xwx_b965d709c03bc5b8.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_c5f77c5f29bd65bd': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'JL.',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Manuel',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_c81e8ac8a5a2e58e': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Alegre',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Comentador',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_cbb24d5d505f2598': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Ruiz-Castillo',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Daniel',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_cd5f42d2869945cc': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Perez',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Antonio',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_dbef17442ba0c5ce': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Mur',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Muril',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/7/35/xwx_dbef17442ba0c5ce.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'xwx_ec2aeb41bb20c5c5': {'activo': 0,
#    'alias_bonito': '',
#    'apellidos': 'Gumball',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'Gumball',
#    'pathfoto': '',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''},
#   'zhu_en': {'activo': 0,
#    'alias_bonito': 'zhu_en',
#    'apellidos': 'de bosque',
#    'bloqueado': 0,
#    'descripcion': '',
#    'nombre': 'claro',
#    'pathfoto': 'http://ep01.epimg.net/miperfil/avatares/4/35/zhu_en.jpg',
#    'seguido': 0,
#    'tipo_usuario': '',
#    'urlblog': '',
#    'urltwitter': '',
#    'urlwebpersonal': ''}},
#  'ts': '1565339664.14787197'}

# %%
def extractComments(commentsObjectList, urlNoticia="", specialCase = False):
    print(" \t -> parsing comments list with -{}- elements:".format(len(commentsObjectList)))
    parsedComments = []
    listToParse = commentsObjectList[1] if specialCase else commentsObjectList
    for commentObj in listToParse:
        fechaObj = datetime.datetime.fromtimestamp(commentObj["tsMensaje"])
        fechaStr = fechaObj.strftime("%d/%m/%Y-%H:%M:%S")
        fechaArr = fechaStr.split("-")
        parsedComment = {
            "urlNoticia": urlNoticia,
            "fecha": fechaArr[0],
            "hora": fechaArr[1],
            "user": commentObj['usuarioOrigen'],
            "commentario": commentObj['contenido']
        }
        parsedComments.append(parsedComment)
    return parsedComments

# %%
parsedComments = extractComments(commentsResponse["mensajes"], url)
# Out:
#  	 -> parsing comments list with -121- elements:

# %%
parsedComments
# Out:
# [{'commentario': '<p>Tres millones de hectáreas de bosques arden en Rusia <a title="http://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html" target="_blank" href="http://cort.as/-MEWg">http://cort.as/-MEWg</a></p>',
#   'fecha': '01/08/2019',
#   'hora': '15:08:56',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'registrador'},
#  {'commentario': '<p>Aún no toman en serio el calentamiento global. Las pérdidas económicas son mayores cada año. </p><p>Los gobiernos deben invertir para cambiar la matriz de energía, que aún sigue siendo petróleo, gas y carbón porque por más que crecen las energías verdes, cada año se necesita más y más energía: <a title="http://cort.as/9VGN" target="_blank" href="http://cort.as/9VGN">http://cort.as/9VGN</a> no hay que dejarlo al mercado, porque se está yendo más lento de lo que el planeta necesita. <a title="http://cort.as/-0X8m" target="_blank" href="http://cort.as/-0X8m">http://cort.as/-0X8m</a> No hay otra solución. </p><p>Asimismo, debería haber un plan global para reponer árboles, ya que sólo en América Latina todos los años se pierde por la tala una superficie equivalente a Bélgica, es como si le quitaras al mundo un pedazito de pulmón. </p><p>Sólo una ayuda divina de la jerarquía espiritual, que se presentará en poco tiempo, con Maitreya, Jesús, Koot homi, Morya, Hilarión, Rackozy, Pablo el Veneciano y otros maestros, nos presentarán el panorama de crisis completo, no sólo ecológico, sino en varios aspectos: <a title="http://cort.as/8lVy" target="_blank" href="http://cort.as/8lVy">http://cort.as/8lVy</a> Este será el evento más importante en la historia de la humanidad. Los problemas que afronta el mundo son varios: <a title="http://cort.as/djmz" target="_blank" href="http://cort.as/djmz">http://cort.as/djmz</a> <a title="http://cort.as/-99f3" target="_blank" href="http://cort.as/-99f3">http://cort.as/-99f3</a></p>',
#   'fecha': '01/08/2019',
#   'hora': '15:41:05',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'mapereira'},
#  {'commentario': '<p>Esto es un verdadero desastre ecológico, pues es zona de turba y si está seca puede estar eso ardiendo mucho tiempo, además de la cantidad ingente de CO2 que emite. 3 millones de hectáreas no es poco</p>',
#   'fecha': '01/08/2019',
#   'hora': '15:52:45',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_91d27da053f285c4'},
#  {'commentario': '<p>Esto ocurre cada año desde tiempos inmemorables. Y no le pasa nada a la planeta. Estos incendios no están debidos como los incendios en España por el afán de recalificar tierras.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:15:18',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'kbz'},
#  {'commentario': '<p>Estas cantidades inabarcables ,me dan risa</p>',
#   'fecha': '01/08/2019',
#   'hora': '16:06:56',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_a39901c1357825a4'},
#  {'commentario': '<p>30.000 km2, el tamaño aproximado de Galicia, algo "inabarcable" sin duda. Lo suyo debe ser la risa tonta del que poco sabe.</p>',
#   'fecha': '01/08/2019',
#   'hora': '17:39:59',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'mjmingo9'},
#  {'commentario': '<p>Desde luego, aun considerando la enorme extensión que tiene Siberia (Unos 10 millones de Km/2) es una catástrofe en toda  regla que ardan 30.000 km/2. En esa extensión caben 4 provincias del tamaña de la de Málaga.</p>',
#   'fecha': '01/08/2019',
#   'hora': '18:04:13',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'claudio3'},
#  {'commentario': '<p>3 millones de hectáreas son 30.000km², el tamaño de Galicia, es un auténtico desastre. Espero que se solucione pronto.</p>',
#   'fecha': '01/08/2019',
#   'hora': '16:20:39',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'psalazar'},
#  {'commentario': '<p>Tranqi, no pasa nada. El ejército hará buen ejercicio bombardeando (para hacer bandas sin árboles). No sé si tiene sentido.  El mapa está tan exajerada como solo el país puede exagerar.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:17:20',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'kbz'},
#  {'commentario': '<p>El político dice : no vale la pena luchar contra el fuego. Vale más lo que enviamos a luchar contra el fuego que lo que se quema. Y ese es el problema. Los bosques no cotizan en bolsa, no valen nada desde el punto de vista capitalista. Sólo su transformación en viviendas y comercios y fábricas. Son los árboles los que nos permiten respirar. Y lo hacen gratis. Algo inconcebible en nuestro sistema económico.</p>',
#   'fecha': '01/08/2019',
#   'hora': '16:51:54',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_b965d709c03bc5b8'},
#  {'commentario': '<p>Lo de la Amazonia es un topicazo aunque haya que protegerla. La Taiga o bosque boreal de Eurasia es el verdadero pulmón del planeta y su protección debería ser un compromiso de todos los paises. La extensión del desastre es descomunal.</p>',
#   'fecha': '01/08/2019',
#   'hora': '17:00:32',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_6a6021bf0e38c5be'},
#  {'commentario': '<p>El cambio climático ya está aquí y es irreversible. Bienvenidos al apocalipsis.</p>',
#   'fecha': '01/08/2019',
#   'hora': '17:39:59',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'cientifico'},
#  {'commentario': '<p>A mí lo que me ha dejado más preocupado es que Estados Unidos se haya ofrecido a ayudar, a un país "enemigo" y encima en un tema ambiental, sabiendo de la posición del actual presidente sobre este asunto. Realmente mal debe pintar el tema para llegar a ese punto.</p>',
#   'fecha': '01/08/2019',
#   'hora': '17:58:53',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'anonimo_1001'},
#  {'commentario': '<p>Sigues sin verlo. La culpa es de Rajoy.</p>',
#   'fecha': '01/08/2019',
#   'hora': '18:08:37',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_1315288e75236582'},
#  {'commentario': '(mensaje borrado)',
#   'fecha': '01/08/2019',
#   'hora': '17:58:53',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'blancoxdentroyxfuera'},
#  {'commentario': '<p>Por fin hace algo correcto ese ex funcionario del KGB ante la catástrofe.....</p>',
#   'fecha': '01/08/2019',
#   'hora': '18:10:09',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_dbef17442ba0c5ce'},
#  {'commentario': '<p>Todo el mundo tiene ingentes cantidades de material para destruir, para matar, para exterminar pero curiosamente ningún país tiene los suficientes medios para defenderse de la naturaleza, de la devastación del fuego, de los huracanes, de las sequías, etc, etc... Creo que deberíamos pensar muy bien cuáles son nuestras prioridades,</p>',
#   'fecha': '01/08/2019',
#   'hora': '18:10:28',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'glopllu'},
#  {'commentario': '<p>Es algo increíble...Miro el mapa y me angustio. Lo siguiente será tierra devastada, como el Sáhara.</p>',
#   'fecha': '01/08/2019',
#   'hora': '18:49:55',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'fedfan'},
#  {'commentario': '<p>Tiene una solución dificil lo de los incendios forestales, la mayoría parece ser que son provocados, y el que lo hace busca la mayor ventaja posible para que tenga éxito. Creo que habría que extremar la prevención... una vez el fuego  cobra fuerza, los aviones le dan risa. Penas fuertes para los delincuentes, pero no de cárcel, sino de limpieza de montes de por vida útil.</p>',
#   'fecha': '01/08/2019',
#   'hora': '21:58:36',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_506c7caf42366582'},
#  {'commentario': '<p>40. - Los incendios forestales que arrasan estos días vastos territorios de Siberia podrían ser deliberados, para encubrir la tala ilegal, admitió el primer ministro de Rusia, Dmitri Medvédev. 01.08.2019 </p><p><a title="http://cort.as/-MHAf" target="_blank" href="http://cort.as/-MHAf">http://cort.as/-MHAf</a></p>',
#   'fecha': '02/08/2019',
#   'hora': '02:13:05',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cd5f42d2869945cc'},
#  {'commentario': '<p>Limpiar bosques inaccesibles es como barrer la arena del desierto. Absurdo.</p>',
#   'fecha': '02/08/2019',
#   'hora': '12:11:38',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'frippy'},
#  {'commentario': '<p>Inaccesibles para una de las mayores potencias mundiales, con la de máquinas que hay, eso hace 100 años aún.</p>',
#   'fecha': '02/08/2019',
#   'hora': '20:57:42',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_506c7caf42366582'},
#  {'commentario': '<p>Espeluznante. </p><p><a title="http://cort.as/-MFA0" target="_blank" href="http://cort.as/-MFA0">http://cort.as/-MFA0</a></p>',
#   'fecha': '01/08/2019',
#   'hora': '18:20:21',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_8e716c2fbcf925d3'},
#  {'commentario': '<p>A Putin le importa más si su perro estornuda</p>',
#   'fecha': '01/08/2019',
#   'hora': '18:28:01',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'tonterias'},
#  {'commentario': '<p>Putin hizo las maniobras mas grandes de Rusia ,mas de 300 mil soldados y tanques aviones ,ect ,todo para inutil proposito de mostrar musculo ,aunque si fuera contra la OTAN es en vano ,pero para salvar la naturaleza ,no mueben un dedo ,hasta que el fuego llegue al krenlin ,no es negocio apagarlo ,y trump de lame ojos ,que se retiro del plan de salvar nuestra tierra ,quiere poner el dinero de los americanos a salvar los bosques rusos ,que desverguenza ,politica ,las relaciones con rusia no seran mejores kientras Putin sea el lider ,solo trump por los motivos escondidos que tiene ,le trata de amigo ,sabe Dios ,que le sabe ,algun dia lo sabremos ,cuando Trump salga del poder ,Putin le pasara la cuenta ,ese no es amigo de nadie ,</p>',
#   'fecha': '01/08/2019',
#   'hora': '18:37:40',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_a72d538f537aa5be'},
#  {'commentario': '<p>No se cuanto más hace falta para que la Derecha empiece a reconocer que lo del cambio climático va en serio y no es ninguna patraña marxista. Y esto lo dice alguien que se considera más bien conservador y de derechas</p>',
#   'fecha': '01/08/2019',
#   'hora': '18:43:46',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'pifostio'},
#  {'commentario': '<p>sí, es verdad, es una concienzuda reflexión y creo que la intelectualidad científica no se lo ha planteado. Hay que exterminar de una vez a la Derecha y a los conservantes conservadores que son la causa, el medio y el fin del por-blema medioambiental. Más I+D+I y menos VOX.</p>',
#   'fecha': '01/08/2019',
#   'hora': '18:50:27',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_1315288e75236582'},
#  {'commentario': '<p>Es que yo soy votante de VOX, a pesar de que nieguen el cambio climático.</p>',
#   'fecha': '01/08/2019',
#   'hora': '20:46:39',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'pifostio'},
#  {'commentario': '<p>Que pereza dais</p>',
#   'fecha': '01/08/2019',
#   'hora': '20:55:18',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_47580b46487aa5d2'},
#  {'commentario': '<p>Igual, si dejarais de votarles, dejarían de hablar patrañas.</p>',
#   'fecha': '01/08/2019',
#   'hora': '21:27:44',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'kissin'},
#  {'commentario': '<p>¿Existe la tecnología para provocar lluvias artificialmente?</p>',
#   'fecha': '01/08/2019',
#   'hora': '18:52:28',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'cuchas'},
#  {'commentario': '<p>Y nevadas.</p>',
#   'fecha': '01/08/2019',
#   'hora': '20:23:53',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'heferstion'},
#  {'commentario': '<p>Creo que sí; pero se requiere de humedad existente en la atmósfera claro. Utilizan yoduro de plata.  En cualquier caso no creo que sea facil; de lo contrario se haría con frecuencia.</p>',
#   'fecha': '01/08/2019',
#   'hora': '20:38:35',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'jaimer'},
#  {'commentario': '<p>Han tardado 7 días en empezar a decir algo sobre el desastre ambiental de Siberia... aqui hablamos más de la Pantoja o de alguna pijada LGTBI </p><p>Una amiga siberiana me explicó el desastre y yo le dije aqui no han dicho NADAAA... Ciudades llenas de humo.. bosques calcinados por miles de kilómetros cuadrados.. y El Pais ni mu.... ahora 7 días despues empiezan a decir algo, cuando Trump ofrece ayuda... Cada semana que pasa la gente que trabaja  en EL PAIS  son peores... gastan tiempo y recursos en chorradas de lavado de coco y de las cosas que afectan de verdad no dicen nada o las dicen sesgadas... </p><p>El Clima ha cambiado durante toda la historia el Calentamiento Global es un cuento que se han sacado de la manga para subir impuestos y cobrar por "vender aire" cualquiera que lea historia sabe que ha habido periodos de grandes sequias, desiertos que se han tragado civilizaciones, inundaciones bíblicas, inviernos durísimos que provocaban grandes migraciones.. El Clima siempre es variable.. asi ha sido y asi sera.. pero estos jetas quieren poner un IMPUESTITO AL TEMA..  a chupar del CLIMA.</p>',
#   'fecha': '01/08/2019',
#   'hora': '18:54:30',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_3239024844b5c5b8'},
#  {'commentario': '<p>Pues como cualquiera que haya leído la historia sabe, esto es normal, siempre ha habido grandes incendios en los bosques, nada de qué preocuparse. El País le ha hecho caso ignorando la noticia; ¿por qué se mosquea con el periódico?</p>',
#   'fecha': '01/08/2019',
#   'hora': '19:03:47',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'ahmonge'},
#  {'commentario': '<p>Cansa un poco leer siempre los mismos argumentos falaces. El que el clima siempre varíe no demuestra que el cambio climático actual sea un cuento. El clima varía, sí, pero las variaciones cíclicas son mucho más lentas que lo que estamos viendo ahora. Y cuando ha habido cambios bruscos, siempre se han tenido que deber a algo que los causara: caída de un gran meteorito, fuerte actividad volcánica, cambios en la configuración de los continentes y las aguas... Pero, ¿a qué se debe el calentamiento actual, que está ocurriendo a un ritmo sin precedentes conocidos? A los ciclos solares no. A cambios en la órbita terrestre tampoco, ni a la caída de un meteorito, ni a la actividad volcánica. En cambio, sí está demostrado que el CO2 ha visto aumentada su concentración en la atmósfera debido a la actividad humana, que es, además, un gas de efecto invernadero. ¿Hay alguna otra hipótesis alternativa?</p>',
#   'fecha': '01/08/2019',
#   'hora': '20:46:09',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'pifostio'},
#  {'commentario': '<p>El clima siempre ha variado, pero el hombre está haciendo que varíe miles de veces más rápido, ha destruido el equilibrio natural.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:47:46',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_682cf555e75045ac'},
#  {'commentario': '<p>Lo que tenemos que hacer es no comprar nada que contenga plástico por ejemplo. Porque es absurdo cuando cualquier artículo pequeño, aunque sean 10 tornillos, está empaqueteado en un montón de plástico.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:52:29',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'bill_takoff'},
#  {'commentario': '<p>Podemos rechazar las bolsas plásticas ,en mi país estamos creando una cultura de rechazo, ves a la gente comprando con bolsas de tela si la compra es mayor , o con las cosas en la mano sin son menores. </p><p>Es poco pero por algo se empieza, hasta los inmigrantesse han ido acostumbrando.</p>',
#   'fecha': '02/08/2019',
#   'hora': '04:02:42',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'angelito1950'},
#  {'commentario': '<p>Pues en realidad no es miles  de veces más rápido ,  pero la velocidad de cambio supera la velocidad de adaptación del planeta y ahí está el problema . </p><p>Se supone que el excedente de carbono en la atmósfera hace crecer los árboles , pero eso tiene una velocidad mucho menor que aquella a la que descargamos el CO2.</p>',
#   'fecha': '02/08/2019',
#   'hora': '04:05:43',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'angelito1950'},
#  {'commentario': '<p>Terraplanista detectado.</p>',
#   'fecha': '02/08/2019',
#   'hora': '12:06:32',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'frippy'},
#  {'commentario': '<p>sería bueno entender que los fuegos en la taiga que no provienen de la mano humana... son beneficiosos en general aunque nuestra visión mediterránea nos diga lo contrario.</p>',
#   'fecha': '01/08/2019',
#   'hora': '19:04:48',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'gbshaw'},
#  {'commentario': '<p>Vaya zafiedad, como si aquello fuera la sabana africana...........con el permafrost yéndose al garete.</p>',
#   'fecha': '01/08/2019',
#   'hora': '19:16:44',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_dbef17442ba0c5ce'},
#  {'commentario': '<p>el permafrost no se va al garete (basicamente pq el calor de un incendio por muy potente que sea no pasa de unos cm hacia abajo.....) por los incendios que por cierto son recurrentes año tras año por accion de los rayos.</p>',
#   'fecha': '01/08/2019',
#   'hora': '19:52:24',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'gbshaw'},
#  {'commentario': '<p>¿Centímetros del permafrost en un infierno?.......de traca.</p>',
#   'fecha': '01/08/2019',
#   'hora': '20:21:50',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_dbef17442ba0c5ce'},
#  {'commentario': '<p>De traca no, el calor no pasa de 5 cm en vertical en el suelo y eso es algo muy evidente quizá desde su salón no claro, el permafrost se reduce por el calentamiento global, en nada le afectan los incendios</p>',
#   'fecha': '01/08/2019',
#   'hora': '22:22:25',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'gbshaw'},
#  {'commentario': '<p>Lo que tienes que hacer es no elucubrar sin tener pajolera idea donde estás de pie, en una argumentación inculta y prefabricada por mor de no se sabe bien que intereses........ </p><p>Toma y lee a titulo orientativo y deja de decir sandeces, "5 cm" de opereta, al que semejante incendio "no afecta al permafrost" con semejantes temperaturas y contigo, controlando de testigo, a pie del incendio. Espabila. </p><p><a title="http://cort.as/-MK-J" target="_blank" href="http://cort.as/-MK-J">http://cort.as/-MK-J</a></p>',
#   'fecha': '02/08/2019',
#   'hora': '14:31:58',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_dbef17442ba0c5ce'},
#  {'commentario': '<p>Puff, una superficie mayor que Bélgica!!! No estaría por allí Messie  Puigdemont.....</p>',
#   'fecha': '01/08/2019',
#   'hora': '20:55:49',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'pacoillo'},
#  {'commentario': '<p>El Cambio Climático (que tiene POCO que ver con el Deterioro Ambiental Antropogénico) es obviamente el responsable. Se derrite el permafrost y se libera el metano atrapado en la última glaciación de Siberia (una de incontables)... Cae un rayo y ahí lo tienes...</p>',
#   'fecha': '01/08/2019',
#   'hora': '21:17:37',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'jordihurtado'},
#  {'commentario': '<p>Si se reconoce que el cambio climático es un problema real, se puede tratar de paliar sus consecuencias. Si ni siquiera se es capaz de dar ese primer paso, ...</p>',
#   'fecha': '01/08/2019',
#   'hora': '21:56:45',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cbb24d5d505f2598'},
#  {'commentario': '<p>Claro que es un problema real... Es obvio. </p><p>La discusión es sobre si podemos evitarlo: Mi opinión es que no, hagamos lo que hagamos, bien o mal, porque las FUERZAS que lo están originando, principalmente (el sol, la PRECESIÓN de la Tierra y las erupciones submarinas -desconocidas-) están absolutamente fuera de nuestro antropocéntrico (creernos el ombligo del universo, por lavado de cerebro religioso) control... </p><p>Es obvio también que ALGO contribuimos (muy estudiado)... Pero NADIE sabe en qué PORCENTAJE y lo dicho, mi humilde opinión es que esa conteibución nuestra es insignificante frente a las Fuerzas mencionadas... </p><p>Por eso me irrita el Terrorismo Sicológico Climático...</p>',
#   'fecha': '02/08/2019',
#   'hora': '17:48:48',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'jordihurtado'},
#  {'commentario': '<p>Creo que el mapa no se corresponde con las Ha quemadas, pues la cantidad dicha sería como Bélgica más o menos, de todas formas es alarmante.</p>',
#   'fecha': '01/08/2019',
#   'hora': '21:45:57',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_8e716c2fbcf925d3'},
#  {'commentario': '<p>que fuerte, 3 </p><p>Millones de Has a ver que coja la calculadora....30000 millones de m2 creo.</p>',
#   'fecha': '01/08/2019',
#   'hora': '21:47:59',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_506c7caf42366582'},
#  {'commentario': '<p>Debe haber un error. Si España tiene 500000 km2, es como seis veces nuestro país?</p>',
#   'fecha': '01/08/2019',
#   'hora': '21:55:03',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_506c7caf42366582'},
#  {'commentario': '<p>Un km2 tiene 100 Ha.</p>',
#   'fecha': '01/08/2019',
#   'hora': '22:04:23',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cbb24d5d505f2598'},
#  {'commentario': '<p>Luego 10000 km2 un millón de Ha.</p>',
#   'fecha': '01/08/2019',
#   'hora': '22:14:19',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_506c7caf42366582'},
#  {'commentario': '<p>En un país con millones de km de bosques</p>',
#   'fecha': '02/08/2019',
#   'hora': '04:20:48',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'angelito1950'},
#  {'commentario': '<p>Pues nada, que sigan quemando.</p>',
#   'fecha': '02/08/2019',
#   'hora': '10:08:20',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_506c7caf42366582'},
#  {'commentario': '<p>pues no se trata de  eso, simplemente también en Siberia hay incendios forestales, sólo que los números son siberianos.</p>',
#   'fecha': '02/08/2019',
#   'hora': '23:47:41',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'angelito1950'},
#  {'commentario': '<p>Triste y desolador, quienes niegan el deterioro climático y todas las consecuencias que estamos viendo y viviendo.</p>',
#   'fecha': '01/08/2019',
#   'hora': '22:23:56',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_c81e8ac8a5a2e58e'},
#  {'commentario': '<p>La Tierra tiene un virus que es el ser humano y éstas son las consecuencias.</p>',
#   'fecha': '01/08/2019',
#   'hora': '22:43:41',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'nelamiko'},
#  {'commentario': '<p>Sí, pero eso no dura mucho: ya verás cuando el planeta se pegue un pedo....A ver adónde va a ir tanto humano.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:06:08',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'perthiguez'},
#  {'commentario': '<p>Muchos de estos incendios estan provocados por rayos. Ha habido incendios forestales toda la vida, antes de que existieran los humanos.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:13:16',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_21b36bfac5a5c5a1'},
#  {'commentario': '<p>Correcto y es la forma que usa la naturaleza para renovar el bosque .</p>',
#   'fecha': '02/08/2019',
#   'hora': '04:18:17',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'angelito1950'},
#  {'commentario': '<p>Hoy toca censor en los comentarios de El País.</p>',
#   'fecha': '01/08/2019',
#   'hora': '22:56:49',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_c5f77c5f29bd65bd'},
#  {'commentario': '<p>Creo que esto pasa todos los años en los bosques de Siberia, igual que en Galicia pero a menor escala. En Siberia en verano hace mucho calor y no llueve mucho, así  que cualquier chispa puede provocar un incendio enorme ya que allí casi no hay población. Cuando hice un transiberiano hace tres años y paré 3 días en la ciudad de Ulan-Ude cerca del lago Baikal, toda la ciudad y los alrededores estaban llenos de humo por los incendios forrestales. Pero por lo que vi, la gente estaba acostumbrada a eso y no le hacía mucho caso. No se veía bien, era como una niebla espesa pero se respiraba con normalidad</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:03:56',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'bill_takoff'},
#  {'commentario': '<p>Cuando todo está hecho un chicharrón, manda Putin al ejército a echarle agua a los rescoldos. </p><p>Eso pasa cuando todo depende del dictador de turno...</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:04:57',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'perthiguez'},
#  {'commentario': '<p>Llamar a un presidente, elegido democráticamente  por los ciudadanos de un país en unas elecciones libres, dictador, no es correcto desde cualquier punto de vista...</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:28:49',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'bill_takoff'},
#  {'commentario': '<p>48. La aviación de los Ministerios de Defensa y de Emergencias de Rusia extinguieron en un día incendios en una superficie de 23.000 hectáreas en la región de Krasnoyarsk, informó el viceministro de Defensa ruso, general de Ejército Dmitri Bulgákov </p><p><a title="http://cort.as/-MHBF" target="_blank" href="http://cort.as/-MHBF">http://cort.as/-MHBF</a></p>',
#   'fecha': '02/08/2019',
#   'hora': '02:15:07',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cd5f42d2869945cc'},
#  {'commentario': '(mensaje borrado)',
#   'fecha': '02/08/2019',
#   'hora': '02:53:22',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_b7cb0c7253ce05d1'},
#  {'commentario': '<p>Vaya ,  al menos este "dictador " se preocupa , el dictador de turno de USA ni se lamentó por las muertes causadas por los incendios .</p>',
#   'fecha': '02/08/2019',
#   'hora': '04:19:47',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'angelito1950'},
#  {'commentario': '<p>De todo punto de vista una decisión muy acertada.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:10:11',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'zhu_en'},
#  {'commentario': '<p>Como? A Cañonazos?</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:12:45',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_21b36bfac5a5c5a1'},
#  {'commentario': '<p>Un alarmante pronóstico sobre el calentamiento global para 2050 ya se ha superado este verano </p><p>El panorama catastrofista previsto para mediados de este siglo ha quedado desfasado en solo cinco años. </p><p>En 2014, el canal francés TF1 empleó algunas de las previsiones más extremas de la Organización Meteorológica Mundial (OMM) para elaborar un informe climático sobre las temperaturas que tendría Francia a mediados de este siglo. </p><p><a title="http://cort.as/-MGR7" target="_blank" href="http://cort.as/-MGR7">http://cort.as/-MGR7</a></p>',
#   'fecha': '01/08/2019',
#   'hora': '23:19:21',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_ec2aeb41bb20c5c5'},
#  {'commentario': '<p>Ohhh,  usted no es tan bruto,  como se esfuerza en mostrarse siempre  vaya es una agradable sorpresa , al menos tiene un lado inteligente.</p>',
#   'fecha': '02/08/2019',
#   'hora': '04:16:16',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'angelito1950'},
#  {'commentario': '<p>La Tierra, puede sin ningún problema albergar más de 45 veces  los habitantes humanos actuales.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:27:25',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_a39901c1357825a4'},
#  {'commentario': '<p>Y si todos tuvieran tu sabiduría, la Tierra podría abelgar hasta 145 veces los habitantes actuales</p>',
#   'fecha': '02/08/2019',
#   'hora': '00:40:53',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'vientoquevayviene'},
#  {'commentario': '<p>Que????? </p><p>Con la población actual llegamos al 28 de julio con los recursos que produce el planeta , el resto del año es deficit acumulado . </p><p>Países como qatar , Israel y USA no llegan a abril. </p><p>Si todos consumiéramos como consume Francia ocuparíamos dos planetas y si consumiéramos como  USA necesitaríamos cinco planetas . </p><p>No hay alternativas , hay hacer la paz cn el planeta . </p><p>Nunca podremos irnos de aquí , no hay adónde ir, la física es inapelable , los viajes espaciales fuera del entorno terrestre son imposibles por física relativista.</p>',
#   'fecha': '02/08/2019',
#   'hora': '04:14:45',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'angelito1950'},
#  {'commentario': '<p>El ser humano es lo peor que hay encima de la Tierra. Que salvajada. </p><p>Una pena.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:31:59',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_78e09a8866702593'},
#  {'commentario': '<p>Cuando no había hombres en la tierra, ya había incendios que duraban meses y meses porque ni siquiera había aviones que los apagaran. De allí tenemos tanto carbón</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:35:14',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'bill_takoff'},
#  {'commentario': '<p>Creo que su premisa es correcta, pero su tesis final es completamente equivocada, ya que en la época wn la que se "creó" el carbón el ser humano no era ni proyecto, y hoy en día el propio ser humano se está suicidando más otros cuantos seres vivos que, mire usted, ellos no quieren.</p>',
#   'fecha': '02/08/2019',
#   'hora': '00:38:52',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_78e09a8866702593'},
#  {'commentario': '<p>Correcto, no era ni proyecto ,  el Carbonífero de 360 a 318 millones ANE. </p><p>Los primeros terapsidas don de hace unos 250 millones y los primeros primates de hace unos 60 millones ,  la separación de la línea homo de la línea chimpancé hace unos 6 millones de años , talvez siete. </p><p>El hombre moderno no más de 320 mil años y quizás menos. </p><p>Es bonito el tema</p>',
#   'fecha': '02/08/2019',
#   'hora': '03:59:11',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'angelito1950'},
#  {'commentario': '<p>También tendrá su encanto turístico caminar días y días por unos terrenos abrasados sin vida y silenciados los pasos por las cenizas.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:33:00',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_a39901c1357825a4'},
#  {'commentario': '<p>hola Postolo </p><p>Gloria a grande Putin !!!  Gloria a tu Madre Rusia !!!! </p><p>trabajas hoy ?</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:35:02',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xixidoc'},
#  {'commentario': '<p>España tiene 50.000.000 de Hc. todavía queda tela</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:36:33',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_a39901c1357825a4'},
#  {'commentario': '<p>Esta es la razón por la que las previsiones más catastróficas sobre el cambio climático van a quedarse muy cortas, los bosques que hasta hace diez años eran seguros ahora van a arder a velocidades desconocidas hasta ahora, Portugal, Rusia, España, Rumanía, California. La pérdida de masa forestal va a ser dantesca, con lo cual el desequilibrio en la atmósfera se disparará vertiginosamente. Creo que el Nuremberg a los negacionistas del cambio no debe esperar, van a matar a millones de personas, Trump, Bolsonaro, Putin y compañía cadena perpetua.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:44:08',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_1e14a176217b45a5'},
#  {'commentario': '<p>Y Obama de fiscal junto con Clinton y los artistas holiwoodienses</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:50:19',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_a39901c1357825a4'},
#  {'commentario': '<p>¿Estás seguro que con la ultra izquierda radical de Obama no habría ningún incendio forestal en el planeta?</p>',
#   'fecha': '02/08/2019',
#   'hora': '00:10:56',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'bill_takoff'},
#  {'commentario': '<p>"Ultra izquierda radical de Obama" ... jajajajajajajajajajajajajaa ¿vosotros que teneis en la cabeza?</p>',
#   'fecha': '02/08/2019',
#   'hora': '02:53:52',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_b7cb0c7253ce05d1'},
#  {'commentario': '<p>63. -"Los esfuerzos de Rusia han permitido frenar durante un año el calentamiento global", ha señalado el presidente ruso,  Putin, en su discurso en la sesión plenaria de la Cumbre del Clima, que se celebra en la capital francesa. El evento ha reunido a  representantes de casi todos los países del mundo para intentar encontrar soluciones el cambio climático. 30 nov 2015 </p><p><a title="http://cort.as/-MHCg" target="_blank" href="http://cort.as/-MHCg">http://cort.as/-MHCg</a></p>',
#   'fecha': '02/08/2019',
#   'hora': '02:19:09',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cd5f42d2869945cc'},
#  {'commentario': '<p>Putin es conservacionista, hasta colabora con  temas ambientales de su propio peculio.</p>',
#   'fecha': '02/08/2019',
#   'hora': '04:07:13',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'angelito1950'},
#  {'commentario': '(mensaje borrado)',
#   'fecha': '02/08/2019',
#   'hora': '10:21:38',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cd5f42d2869945cc'},
#  {'commentario': '<p>88. Hola Jor.... Bueno, hay que reconocer que la “lectura rápida” de algunas de sus declaraciones podría dejar a entender su alineamiento ideológico con negacionistas como Trump o Bolsonaro. </p><p>Ahora, se puede comprobar que tanto sus decisiones legislativas como las políticas a largo plazo de la Federación Rusa van encaminadas a la protección medio ambiental. Cosa que no sucede en los casos de Trump o Bolsonaro. </p><p>Por otra parte, no tiene mucho interés saber cómo gasta Putin sus recursos financieros personales y SÍ como ha progresado su patrimonio familiar o si esto concuerda con una gestión honesta/adecuada de los intereses públicos. </p><p>Saludos</p>',
#   'fecha': '02/08/2019',
#   'hora': '11:01:57',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cd5f42d2869945cc'},
#  {'commentario': '<p>Esas clases de español, pecunio, lo de peculio sería una interesante expresión para un humorista inventor de palabras.</p>',
#   'fecha': '02/08/2019',
#   'hora': '11:41:40',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_1e14a176217b45a5'},
#  {'commentario': '<p>Disculpe, caballero, pero ambas palabras son correctas. <a title="https://dle.rae.es/?id=SHjcEyS" target="_blank" href="http://cort.as/-MJfk">http://cort.as/-MJfk</a></p>',
#   'fecha': '02/08/2019',
#   'hora': '11:56:38',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'jprn'},
#  {'commentario': '<p>Me gusta el estilo de Rodrigo Fernández: informa sin politizar. María Sahuquillo debería hacer lo mismo...</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:45:50',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'bill_takoff'},
#  {'commentario': '<p>Claro, gloria al Zar.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:47:13',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'nessus'},
#  {'commentario': '<p>Por lo menos no es un cómico como lo es el de tu país, aunque reconozco que el anterior era mucho peor.</p>',
#   'fecha': '01/08/2019',
#   'hora': '23:55:21',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'bill_takoff'},
#  {'commentario': '<p>65. - Rusia no está de acuerdo con la postura de Estados Unidos sobre el clima, Venezuela e Irán, declaró el presidente ruso, Vladímir Putin, en la reunión con los jefes de las agencias de noticias internacionales. 06.06.2019 </p><p><a title="http://cort.as/-MHCx" target="_blank" href="http://cort.as/-MHCx">http://cort.as/-MHCx</a></p>',
#   'fecha': '02/08/2019',
#   'hora': '02:20:10',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cd5f42d2869945cc'},
#  {'commentario': '<p>Postolo , estas seguro que dar miedo es mejor que estar divertido ?</p>',
#   'fecha': '02/08/2019',
#   'hora': '00:02:25',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xixidoc'},
#  {'commentario': '<p>Hay diferencias entre intervenir y prevenir, es imposible asegurarse totalmente y menos a una escala global , los cuerpos de intervención immédiata ante desastres es una opción de cada país y cada uno sus propios protocolos ,cuando se ven los incendios en Florida en Portugal o España etc se debería de tener los dispositivos inmediatamente disponibles y debería de verse si  la implementación de recursos hace falta , también hace falta un seguimiento de  la situación en la que se encuentran los lugares más vulnerables ,saber si se está haciendo todo lo que se puede en prevención ,los gobiernos independientemente de las ideologías son responsables pero sin la presión de la opinión pública y sin la exigencia de querer saber que se hizo y de qué medios se dispuso y si más medios o prevención hubieran podido evitarlo o disminuir los efectos no se moverán en una dirección de prevención, probablemente por el coste que implica el aumento de esos medios y ese ahorro puede tener consecuencias devastadoras, se me hace evidente que deberían hacerlo desde ya mismo por el grado de peligrosidad al que estamos llegando</p>',
#   'fecha': '02/08/2019',
#   'hora': '00:25:43',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_59d14448e1a065a6'},
#  {'commentario': '<p>Este jueves se ha decidido provocar artificialmente lluvias para tratar de sofocar las llamas en algunas regiones. </p><p>Y esta frasecita? No hay nada noticiable en esto? incendios hay todos los veranos pero no se suele admitir todos los dias que se crea lluvia artificial para apagarlos.</p>',
#   'fecha': '02/08/2019',
#   'hora': '00:34:18',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'josechuleton'},
#  {'commentario': '<p>La metodología nos es nueva , ya se ha hecho con anterioridad,  debe haber agua disponible si no , ni siendo chamán</p>',
#   'fecha': '02/08/2019',
#   'hora': '03:59:41',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'angelito1950'},
#  {'commentario': '<p>Sin duda alguna , la culpa es de Putin, es lo más probable diría doña Teresa May</p>',
#   'fecha': '02/08/2019',
#   'hora': '03:52:39',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'angelito1950'},
#  {'commentario': '<p>Los incendios en esa zona son normales y hasta necesarios para muchas especies para sobrevivir. El invierno llegará en 1 mes y medio. En Yakutia las primeras nieves caen a mitad finales de septiembre y para mitad de octubre las temperaturas no superan los 0 grados hasta abril.</p>',
#   'fecha': '02/08/2019',
#   'hora': '04:00:25',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_56fa13ad73ba457a'},
#  {'commentario': '<p>Ni Putin ni Trump dicen creer en el cambio climático. ¿Creen en algo?.</p>',
#   'fecha': '02/08/2019',
#   'hora': '08:11:28',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'perron314'},
#  {'commentario': '<p>94. Dices ¿Creen en algo? Hombre yo creo que sí:   (lo básico) </p><p>-Trump: En el aumento de su fortuna personal y en incorporar/dejar a su familia en las élites financieras/políticas del orden social/económico liberal. Y después, ya veremos qué más puede hacer América por mí. </p><p>-Putin: En hacer que los Rusos/Rusia vuelva al estatus de superpotencia y que la riqueza quede/reparta en el pueblo Ruso. Y participar en el nuevo orden/equilibrio más justo entre los pueblos/naciones. </p><p>Es decir, si creen y son antagónicos.</p>',
#   'fecha': '02/08/2019',
#   'hora': '11:25:21',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cd5f42d2869945cc'},
#  {'commentario': '<p>Más bien gemelos idénticos, populismo cercano al neofascismo, escasa sensibilidad democrática, nulo respeto a minorías, nacionalismo barato, agresividad contraproducente, intento de acabar con la democracia más avanzada para evitar modelos incómodos (promoción y financiación de extremismos antieuropeos)....Y en el futuro socios "empresariales", no faltará Berlusconi a la cita.</p>',
#   'fecha': '02/08/2019',
#   'hora': '11:37:05',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_1e14a176217b45a5'},
#  {'commentario': '<p>102. Por favor....... Putin es más guapo, musculado y tiene más sentido del humor. (un poquitin más bajito, eso si) </p><p>-El economista y científico político estadounidense Paul Craig Rober en uno de sus artículos para la revista Foreign Policy reconoció que el jefe del estado ruso, Vladimir Putin, es el único líder.... 02 de enero de 2019 10 </p><p><a title="http://cort.as/-E8DZ" target="_blank" href="http://cort.as/-E8DZ">http://cort.as/-E8DZ</a></p>',
#   'fecha': '02/08/2019',
#   'hora': '12:06:32',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cd5f42d2869945cc'},
#  {'commentario': '<p>102. Por favor....... Putin es más guapo, musculado  ...... </p><p>Antonio , mi ruso amigo, eres chica ? je je je je je</p>',
#   'fecha': '02/08/2019',
#   'hora': '12:39:44',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xixidoc'},
#  {'commentario': '<p>Señora, todos mis respetos, supera con creces todas mis expectativas poder conversar con la abuela de Vladimir.</p>',
#   'fecha': '02/08/2019',
#   'hora': '13:12:59',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_1e14a176217b45a5'},
#  {'commentario': '<p>113. Hummm........ Dado el nivel intelectual que marcas creo que debes dejar también los derivados de ayahuasca.</p>',
#   'fecha': '02/08/2019',
#   'hora': '13:44:05',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cd5f42d2869945cc'},
#  {'commentario': '<p>Lleva usted razón . Sin querer le he puesto un negativo que era para el comentario al que contestaba usted; vivo en Rusia y doy fe de que para afirmar que Putin está a pensando en que la riqueza de Rusia sea para “el pueblo ruso” hay que tener una ignorancia, un cinismo, una ceguera y una cerrazón supina. Es como afirmar que en la URSS gracias a sus dirigentes el pueblo ruso vivía en la riqueza y libres a diferencia de Europa occidental. Para Putin las personas en Rusia son un recurso más , igual que el gas o el petróleo. Un recurso volátil que hay que saber manipular con cuidado , pero nada más. En lo del restaurar el imperialismo ruso sí que tiene razón el forero al que usted respondía. Ese es el objetivo más claro del mandatario ruso.</p>',
#   'fecha': '02/08/2019',
#   'hora': '12:32:35',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'antaresnomilo'},
#  {'commentario': '<p>Por cierto,  dices " vivo en Rusia y doy fe"  -Millán Astray era español y eso no garantizo nada (en sí mismo) a los españoles. </p><p>Además, entérate un poco sobre qué pasa/hacen en tu país y deja los cotilleos de escalera. </p><p>Y de la URSS (leyendo el comentario) no tienes ni pajolera idea, si hasta Langley ha actualizado su manual.</p>',
#   'fecha': '02/08/2019',
#   'hora': '12:52:29',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cd5f42d2869945cc'},
#  {'commentario': '<p>Con el cambio clímatico zonas como Siberia, Alaska o el norte de Canada van a tener que prepararse para luchar contra incendios enormes.</p>',
#   'fecha': '02/08/2019',
#   'hora': '09:05:42',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_aa7911dc9a462593'},
#  {'commentario': '<p>Eso está más claro que el agua... que no les llega de la naturaleza para apagarlos como antes</p>',
#   'fecha': '02/08/2019',
#   'hora': '10:48:08',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'zhu_en'},
#  {'commentario': '<p>"La orden del líder ruso para que los soldados se unan a los bomberos llegó después de que una serie de personalidades de la cultura..." </p><p>Ya tardó menos que Mariano Rajoy con los hilillos de chapapote.</p>',
#   'fecha': '02/08/2019',
#   'hora': '10:17:32',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_3dab830963d96578'},
#  {'commentario': '<p>Es lamentable pensar que una superficie como Bélgica o los Países Bajos pueda estar ardiendo.</p>',
#   'fecha': '02/08/2019',
#   'hora': '11:57:45',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'jprn'},
#  {'commentario': '<p>yo también quería contestar al amigo Antonio 102..., el de la KGB, ese que se ha sacado de la manga un artículo de no sé qué revista foreign no sé qué... habrá que ser carota para dirigirnos a semejante panfleto publicitario prosoviético. Putin le está vendiendo a China gas licuado en cantidades ingentes y el neocomunismo nos adoctrina blanqueando al coloso oriental con sesudos informes de la reducción de emisiones de CO2... podrían explicarnos por qué Putin es el mejor-único socio en el proyecto de ingreso de China en la gobernabilidad del Ártico. Lean un poco sobre ello... me parece realmente espeluznante, el calentamiento por la apertura de nuevas vías marítimas comerciales por allí. La progresía calla, están en los twitts de Trump.</p>',
#   'fecha': '02/08/2019',
#   'hora': '12:58:37',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_1315288e75236582'},
#  {'commentario': '<p>112. Por cierto, no es  102 es 101 , la KGB ahora es FSB y el articulo logicamante no lo he sacado de la manga (estoy en camiseta de tirantes) . Bueno, dadas las precisiones iniciales dudo de la "objetividad del resto del post" no veo el interés en contestarte. Lo siento.</p>',
#   'fecha': '02/08/2019',
#   'hora': '13:19:36',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'xwx_cd5f42d2869945cc'},
#  {'commentario': '<p>Os mando una foto recién hecha en San Petersburgo que demuestra que el calentamiento global es una fake news</p>',
#   'fecha': '02/08/2019',
#   'hora': '22:30:06',
#   'urlNoticia': 'https://elpais.com/internacional/2019/08/01/actualidad/1564658691_230617.html',
#   'user': 'bill_takoff'}]

# %%
len(parsedComments)
# Out:
# 121
